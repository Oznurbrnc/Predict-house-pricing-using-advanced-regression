# %%
import pandas as pd
pd.set_option('display.max_columns',100)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#linear regression algoritmasını çağırıyoruz
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#train test split veriyi ikiye ayırır biriyle eğitiyor biriyle test eder
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %%
def algo_test(x,y):
  
    L = LinearRegression()
    E = ElasticNet()
    R = Ridge()
    Lass = Lasso()
    ETR=ExtraTreeRegressor()
    GBR=GradientBoostingRegressor()
    XGBC= XGBRegressor()
          
    x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=13)
    
    algos = [L,E,R,Lass,ETR,GBR,XGBC]
    algo_names = ['Linear','ElasticNet','Ridge','Lasso','Extra Tree','Gradient Boosting','XGradientBooting']
    r_squared = []
    rmse = []
    mae = []
        
    result = pd.DataFrame(columns = ['R_Squared','RMSE','MAE'],index = algo_names)
       
    for algo in algos:
        algo.fit(x_train,y_train)
             
        r_squared.append(r2_score(y_test,algo.predict(x_test)))
        rmse.append(mean_squared_error(y_test, algo.predict(x_test))**.5)
        mae.append(mean_absolute_error(y_test, algo.predict(x_test)))

    result.R_Squared = r_squared
    result.RMSE = rmse
    result.MAE= mae
    
    return result.sort_values('R_Squared', ascending=False)

# %%
df1=pd.read_csv("train.csv")
df2=pd.read_csv("test.csv")

# %%
df1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df1.shape,df2.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
df1.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df2.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
y=df1['SalePrice']

# %%
df=df1.append(df2)#df1 ve df2 dosyasını altalta birleştirip yeni bir df dosyasına atıyoruz.

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
sns.boxplot(x=df['YearBuilt'])
# Out:
# <AxesSubplot:xlabel='YearBuilt'>

# %%
del df['SalePrice']
#append yapıp birleştirdiğimizde df2 de saleprice bölümü hep NaN ve doldurmmızı gerektirmemesi içinsaleprice sütununu sildik

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
empty=df.isnull().sum()
empty[empty>0]#sadece boş olan sütunların kaç tane boş satırı olduğunu gösterir.
# Out:
# MSZoning           4
# LotFrontage      486
# Alley           2721
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        24
# MasVnrArea        23
# BsmtQual          81
# BsmtCond          82
# BsmtExposure      82
# BsmtFinType1      79
# BsmtFinSF1         1
# BsmtFinType2      80
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# Electrical         1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu     1420
# GarageType       157
# GarageYrBlt      159
# GarageFinish     159
# GarageCars         1
# GarageArea         1
# GarageQual       159
# GarageCond       159
# PoolQC          2909
# Fence           2348
# MiscFeature     2814
# SaleType           1
# dtype: int64

# %%
df['MSZoning']=df['MSZoning'].fillna(df['MSZoning'].mode()[0])
#MSZoning:Genel imar sınıflandırması

# %%
df["LotFrontage"]=df["LotFrontage"].fillna(df["LotFrontage"].mode()[0])
#LotFrantage:Arsa Cephesi

# %%
df["Alley"]=df["Alley"].fillna("None")
#Alley:sokak erişim türü

# %%
df["Utilities"]=df["Utilities"].fillna("None")
#Utilities:Mevcut yardımcı program türleri

# %%
for col in ('Functional','Electrical','KitchenQual','Exterior1st','Exterior2nd','SaleType','Utilities'):
    df[col] = df[col].fillna(df[col].mode()[0])
#for döngüsüyle belirlediğimiz sütunları mode ile dolduruyoruz.

# %%
empty=df.isnull().sum()
empty[empty>0]#sadece boş olan sütunların kaç tane boş satırı olduğunu gösterir.
# Out:
# MasVnrType        24
# MasVnrArea        23
# BsmtQual          81
# BsmtCond          82
# BsmtExposure      82
# BsmtFinType1      79
# BsmtFinSF1         1
# BsmtFinType2      80
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# FireplaceQu     1420
# GarageType       157
# GarageYrBlt      159
# GarageFinish     159
# GarageCars         1
# GarageArea         1
# GarageQual       159
# GarageCond       159
# PoolQC          2909
# Fence           2348
# MiscFeature     2814
# dtype: int64

# %%
df["MasVnrArea"] = df["MasVnrArea"].fillna(0)
#MasVnrArea:Metrekare olarak duvar kaplama alanı

# %%
df["MasVnrType"]=df["MasVnrType"].fillna("None")
#MasVnrType :Duvar kaplama tipi

# %%
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars','BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    df[col] = df[col].fillna(0)

# %%
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PoolQC','Fence','MiscFeature'):
    df[col] = df[col].fillna('None')

# %%
empty=df.isnull().sum()
empty[empty>0]#sadece boş olan sütunların kaç tane boş satırı olduğunu gösterir.
# Out:
# Series([], dtype: int64)

# %%
df['MSSubClass'] = df['MSSubClass'].astype(str)#MSSubClass:yapı sınıfı
df['OverallCond'] = df['OverallCond'].astype(str)#OverallCond:Genel durum değerlendirmesi
df['YrSold'] = df['YrSold'].astype(str)#YrSold:yaş
df['MoSold'] = df['MoSold'].astype(str)#MoSold:satılaN AY

# %%
df3=pd.get_dummies(df,drop_first=True)
df3.sample(15)
# Out:
#         Id  LotFrontage  LotArea  OverallQual  YearBuilt  YearRemodAdd  \
# 784   2245         21.0     1596            4       1973          1973
# 190    191         70.0    10570            8       1932          1994
# 570    571         74.0    13101            5       1965          1965
# 1235  1236         96.0    13132            5       1914          1950
# 1248  1249         60.0     9600            6       1917          1950
# 799    800         60.0     7200            5       1937          1950
# 108   1569        124.0    18600            3       1938          1990
# 1252  1253         62.0     9858            5       1968          1968
# 849   2310         48.0     6240            8       2006          2006
# 1087  2548         60.0     9555            5       1979          1979
# 1115  1116         93.0    12085            8       2007          2007
# 262   1723         60.0    12450            5       2003          2004
# ...

# %%
del df3['Id']#ıd etkisi olmadığı için siliyoruz

# %%
df10=df3[:1460]
df20=df3[1460:]

# %%
algo_test(df10,y)
# Out:
#                    R_Squared          RMSE           MAE
# Gradient Boosting   0.678215  45547.155351  19018.422694
# XGradientBooting    0.604091  50521.428307  22134.462917
# Lasso               0.521298  55553.401746  23604.979714
# Linear              0.512883  56039.599218  24169.160580
# Extra Tree          0.492808  57182.649670  31075.253425
# Ridge               0.478494  57983.946558  22236.400025
# ElasticNet          0.385626  62935.329889  25563.467355
